# %%
import midi
import csv

class Estado:
    track = ''
    instrumento = ''
    tempos = []

class Tempo:
    tick_inicial = 'nao informado'
    ms_per_tick = 'nao informado'
    tick_final = 'nao informado'

estado = Estado()
notas_sendo_pressionadas = {}
linhas_csv = []
midi_file = midi.read_midifile("file.mid")
midi_file.make_ticks_abs()


def nota_pressionada(nota):
    pitch = nota.pitch
    notas_sendo_pressionadas[pitch] = nota

def imprimir_informacoes_notas(nota_passada, nota_atual):
    quando_nota_passada_foi_pressionada = converter_tick_para_segundos(nota_passada.tick)
    tempo_atual = converter_tick_para_segundos(nota_atual.tick)
    duracao = tempo_atual - quando_nota_passada_foi_pressionada
    # adaptar o valor da velocidade? velocidade eh a forca que se utiliza determinada nota
    velocidade = nota_atual.data[1] / 128
    # porcentual de velocidade
    canal = nota_atual.channel
    with open('esperanca.csv', 'w') as arquivo:
        writer = csv.writer(arquivo)
        header = ['Start', 'Duration', 'Pitch', 'Velocity', 'Instrument']
        writer.writerow(header)
        
        
    instrumento = f'{canal}-{estado.instrumento}-{estado.track}'
    linha = [quando_nota_passada_foi_pressionada, duracao, nota_atual.pitch, velocidade, instrumento]
    linhas_csv.append(linha)
    
def nota_levantada(nota):
    pitch = nota.pitch
    nota_pressionada = notas_sendo_pressionadas[pitch]
    del notas_sendo_pressionadas[pitch]
    velocity = nota.data[1]
    imprimir_informacoes_notas(nota_pressionada, nota)

def instrumento_selecionado(evento):
    estado.instrumento = evento.text

def track_selecionado(evento):
    estado.track = evento.text
    
def set_tempo(evento):
    mpqn = evento.get_mpqn()
    mpqn = mpqn / 1000
    
    resolution = midi_file.resolution
    ms_per_tick = mpqn / resolution
    tempo = Tempo()
    tempo.tick_inicial = evento.tick
    tempo.ms_per_tick = ms_per_tick
    if(len(estado.tempos) == 0):
        estado.tempos.append(tempo)
    else:
        tempo_passado = estado.tempos.pop()
        tempo_passado.tick_final = tempo.tick_inicial - 1
        estado.tempos.append(tempo_passado)
        estado.tempos.append(tempo)

def converter_tick_para_segundos(tick):
    # tempo 1 - 0 ticks ateh 300 ticks - 100ms per tick
    # tempo 2 - 301 ticks ateh 600 ticks  - 101ms per tick
    # tempo 3 - 601 ticks ateh nao informado - 98ms per tick
    # estou no tick 50? 50 * 100
    # ESTOU NO TICK 350? 300*100 + 50*200
    # ESTOU NO TICK 1200? 300*100 + 300*200 + 600*300
    
    tempos = estado.tempos
    tempo_total = 0
    ultimo_tempo = tempos[0]
    
    for tempo in tempos:
        tick_inicial = tempo.tick_inicial
        tick_final = tempo.tick_final
        if tick_final == 'nao informado' or tick <= tick_final:
            tempo_total += (tick - tick_inicial) * tempo.ms_per_tick
            return tempo_total / 1000
        elif tick > tick_final:
            delta_tempo = tick_final - tick_inicial
            tempo_total += (delta_tempo) * tempo.ms_per_tick
    

for part in midi_file:
    for event in part:
        print(event)
        if event.name == "Note On":
            nota_pressionada(event)
        elif event.name == "Note Off":
            nota_levantada(event)
        elif event.name == "Track Name":
            track_selecionado(event)
        elif event.name == "Instrument Name":
            instrumento_selecionado(event)
        elif event.name == "Set Tempo":
            set_tempo(event)
            
with open('esperanca.csv', 'w', newline='') as arquivo:
    writer = csv.writer(arquivo)
    header = ['Start', 'Duration', 'Pitch', 'Velocity', 'Instrument']
    writer.writerow(header)
    for linha in linhas_csv:
        writer.writerow(linha)
        
# TICK 0 ATEH O TICK 384 O TEMPO VALE 33, 197, 213
# TICK 385 ATEH O TEMPO 768 O TEMPO VALE 20, 10, 53
# Out:
# midi.TrackNameEvent(tick=0, text='TempoTrack', data=[84, 101, 109, 112, 111, 84, 114, 97, 99, 107])
# midi.SetTempoEvent(tick=0, data=[33, 197, 213])
# midi.SetTempoEvent(tick=384, data=[20, 10, 53])
# midi.SetTempoEvent(tick=768, data=[15, 118, 85])
# midi.SetTempoEvent(tick=1152, data=[13, 239, 181])
# midi.SetTempoEvent(tick=1536, data=[16, 18, 149])
# midi.SetTempoEvent(tick=1920, data=[17, 153, 53])
# midi.SetTempoEvent(tick=2304, data=[14, 61, 213])
# midi.SetTempoEvent(tick=2688, data=[15, 196, 117])
# midi.SetTempoEvent(tick=3072, data=[16, 18, 149])
# midi.SetTempoEvent(tick=3456, data=[17, 75, 21])
# midi.SetTempoEvent(tick=3840, data=[14, 61, 213])
# midi.SetTempoEvent(tick=4224, data=[15, 118, 85])
# midi.SetTempoEvent(tick=4608, data=[19, 109, 245])
# midi.SetTempoEvent(tick=4992, data=[18, 131, 149])
# midi.SetTempoEvent(tick=5376, data=[14, 61, 213])
# midi.SetTempoEvent(tick=5760, data=[13, 239, 181])
# midi.SetTempoEvent(tick=6144, data=[15, 196, 117])
# midi.SetTempoEvent(tick=6528, data=[16, 252, 245])
# midi.SetTempoEvent(tick=6912, data=[15, 196, 117])
# midi.SetTempoEvent(tick=7296, data=[14, 61, 213])
# midi.SetTempoEvent(tick=7680, data=[15, 118, 85])
# midi.SetTempoEvent(tick=8064, data=[15, 118, 85])
# midi.SetTempoEvent(tick=8448, data=[15, 105, 72])
# midi.SetTempoEvent(tick=8832, data=[13, 96, 130])
# midi.SetTempoEvent(tick=9216, data=[18, 53, 117])
# midi.SetTempoEvent(tick=9600, data=[20, 10, 53])
# midi.SetTempoEvent(tick=9984, data=[14, 218, 21])
# midi.SetTempoEvent(tick=10368, data=[13, 83, 117])
# midi.SetTempoEvent(tick=10752, data=[18, 131, 149])
# midi.SetTempoEvent(tick=11136, data=[18, 53, 117])
# midi.SetTempoEvent(tick=11520, data=[13, 83, 117])
# midi.SetTempoEvent(tick=11904, data=[16, 18, 149])
# midi.SetTempoEvent(tick=12288, data=[17, 153, 53])
# midi.SetTempoEvent(tick=12672, data=[19, 31, 213])
# midi.SetTempoEvent(tick=13056, data=[15, 196, 117])
# midi.SetTempoEvent(tick=13440, data=[13, 161, 149])
# midi.SetTempoEvent(tick=13824, data=[18, 53, 117])
# midi.SetTempoEvent(tick=14208, data=[17, 153, 53])
# midi.SetTempoEvent(tick=14592, data=[14, 22, 184])
# midi.SetTempoEvent(tick=14976, data=[14, 100, 242])
# midi.SetTempoEvent(tick=15360, data=[19, 31, 213])
# midi.SetTempoEvent(tick=15744, data=[18, 170, 151])
# midi.SetTempoEvent(tick=16128, data=[15, 79, 83])
# midi.SetTempoEvent(tick=16512, data=[23, 23, 117])
# midi.SetTempoEvent(tick=16896, data=[16, 18, 149])
# midi.SetTempoEvent(tick=17280, data=[23, 23, 117])
# midi.SetTempoEvent(tick=17664, data=[16, 174, 213])
# midi.SetTempoEvent(tick=18048, data=[19, 188, 21])
# midi.SetTempoEvent(tick=18432, data=[23, 23, 117])
# midi.SetTempoEvent(tick=18816, data=[20, 10, 53])
# midi.SetTempoEvent(tick=19200, data=[14, 139, 245])
# midi.SetTempoEvent(tick=19584, data=[14, 61, 213])
# midi.SetTempoEvent(tick=19968, data=[16, 96, 181])
# midi.SetTempoEvent(tick=20352, data=[17, 153, 53])
# midi.SetTempoEvent(tick=20736, data=[13, 161, 149])
# midi.SetTempoEvent(tick=21120, data=[14, 139, 245])
# midi.SetTempoEvent(tick=21504, data=[14, 178, 242])
# midi.SetTempoEvent(tick=21888, data=[15, 79, 88])
# midi.SetTempoEvent(tick=22272, data=[15, 40, 53])
# midi.SetTempoEvent(tick=22656, data=[14, 139, 245])
# midi.SetTempoEvent(tick=23040, data=[16, 96, 181])
# midi.SetTempoEvent(tick=23424, data=[16, 18, 149])
# midi.SetTempoEvent(tick=23808, data=[10, 226, 117])
# midi.SetTempoEvent(tick=24192, data=[19, 109, 245])
# midi.SetTempoEvent(tick=24576, data=[19, 188, 21])
# midi.SetTempoEvent(tick=24960, data=[15, 196, 117])
# midi.SetTempoEvent(tick=25344, data=[12, 196, 36])
# midi.SetTempoEvent(tick=25728, data=[15, 105, 102])
# midi.SetTempoEvent(tick=26112, data=[18, 53, 117])
# midi.SetTempoEvent(tick=26496, data=[19, 201, 3])
# midi.SetTempoEvent(tick=26880, data=[18, 118, 167])
# midi.SetTempoEvent(tick=27264, data=[16, 252, 245])
# midi.SetTempoEvent(tick=27648, data=[17, 231, 85])
# midi.SetTempoEvent(tick=28032, data=[18, 131, 149])
# midi.SetTempoEvent(tick=28416, data=[14, 218, 21])
# midi.SetTempoEvent(tick=28800, data=[23, 101, 149])
# midi.SetTempoEvent(tick=29184, data=[14, 61, 213])
# midi.SetTempoEvent(tick=29568, data=[17, 153, 53])
# midi.SetTempoEvent(tick=29952, data=[16, 18, 149])
# midi.SetTempoEvent(tick=30336, data=[15, 118, 85])
# midi.SetTempoEvent(tick=30720, data=[21, 222, 245])
# midi.SetTempoEvent(tick=31104, data=[19, 109, 245])
# midi.SetTempoEvent(tick=31488, data=[15, 118, 85])
# midi.SetTempoEvent(tick=31872, data=[16, 174, 213])
# midi.SetTempoEvent(tick=32256, data=[17, 244, 62])
# midi.SetTempoEvent(tick=32640, data=[19, 18, 236])
# midi.SetTempoEvent(tick=33024, data=[17, 153, 53])
# midi.SetTempoEvent(tick=33408, data=[18, 131, 149])
# midi.SetTempoEvent(tick=33792, data=[30, 106, 117])
# midi.SetTempoEvent(tick=34176, data=[12, 183, 53])
# midi.SetTempoEvent(tick=34560, data=[12, 183, 53])
# midi.SetTempoEvent(tick=34944, data=[22, 201, 85])
# midi.SetTempoEvent(tick=35328, data=[19, 109, 245])
# midi.SetTempoEvent(tick=35712, data=[19, 31, 213])
# midi.SetTempoEvent(tick=36096, data=[25, 123, 80])
# midi.SetTempoEvent(tick=36480, data=[18, 144, 186])
# midi.SetTempoEvent(tick=36864, data=[37, 33, 53])
# midi.SetTempoEvent(tick=37248, data=[12, 183, 53])
# midi.SetTempoEvent(tick=37632, data=[12, 183, 53])
# midi.SetTempoEvent(tick=38016, data=[12, 183, 53])
# midi.SetTempoEvent(tick=38400, data=[76, 255, 45])
# midi.SetTempoEvent(tick=38784, data=[1, 55, 23])
# midi.EndOfTrackEvent(tick=38785, data=[])
# midi.TrackNameEvent(tick=0, text='TimeSignatureTrack', data=[84, 105, 109, 101, 83, 105, 103, 110, 97, 116, 117, 114, 101, 84, 114, 97, 99, 107])
# midi.TimeSignatureEvent(tick=0, data=[2, 1, 18, 8])
# midi.EndOfTrackEvent(tick=1, data=[])
# midi.TrackNameEvent(tick=0, text='lh', data=[108, 104])
# midi.ProgramChangeEvent(tick=0, channel=0, data=[0])
# midi.InstrumentNameEvent(tick=0, text='acoustic grand', data=[97, 99, 111, 117, 115, 116, 105, 99, 32, 103, 114, 97, 110, 100])
# midi.KeySignatureEvent(tick=0, data=[1, 1])
# midi.NoteOnEvent(tick=384, channel=1, data=[64, 127])
# midi.NoteOnEvent(tick=384, channel=1, data=[59, 127])
# midi.NoteOnEvent(tick=384, channel=1, data=[55, 127])
# midi.NoteOffEvent(tick=605, channel=1, data=[64, 127])
# midi.NoteOffEvent(tick=605, channel=1, data=[59, 127])
# midi.NoteOffEvent(tick=605, channel=1, data=[55, 127])
# midi.NoteOnEvent(tick=605, channel=1, data=[64, 127])
# midi.NoteOnEvent(tick=605, channel=1, data=[59, 127])
# midi.NoteOnEvent(tick=605, channel=1, data=[55, 127])
# midi.NoteOffEvent(tick=768, channel=1, data=[64, 127])
# midi.NoteOffEvent(tick=768, channel=1, data=[59, 127])
# midi.NoteOffEvent(tick=768, channel=1, data=[55, 127])
# midi.NoteOnEvent(tick=768, channel=1, data=[64, 127])
# midi.NoteOnEvent(tick=768, channel=1, data=[59, 127])
# midi.NoteOnEvent(tick=768, channel=1, data=[55, 127])
# midi.NoteOffEvent(tick=964, channel=1, data=[64, 127])
# midi.NoteOffEvent(tick=964, channel=1, data=[59, 127])
# midi.NoteOffEvent(tick=964, channel=1, data=[55, 127])
# midi.NoteOnEvent(tick=964, channel=1, data=[64, 127])
# midi.NoteOnEvent(tick=964, channel=1, data=[59, 127])
# midi.NoteOnEvent(tick=964, channel=1, data=[55, 127])
# midi.NoteOffEvent(tick=1152, channel=1, data=[64, 127])
# midi.NoteOffEvent(tick=1152, channel=1, data=[59, 127])
# midi.NoteOffEvent(tick=1152, channel=1, data=[55, 127])
# midi.NoteOnEvent(tick=1152, channel=1, data=[64, 127])
# midi.NoteOnEvent(tick=1152, channel=1, data=[59, 127])
# midi.NoteOnEvent(tick=1152, channel=1, data=[55, 127])
# midi.NoteOffEvent(tick=1336, channel=1, data=[64, 127])
# midi.NoteOffEvent(tick=1336, channel=1, data=[59, 127])
# midi.NoteOffEvent(tick=1336, channel=1, data=[55, 127])
# midi.NoteOnEvent(tick=1336, channel=1, data=[64, 127])
# midi.NoteOnEvent(tick=1336, channel=1, data=[59, 127])
# midi.NoteOnEvent(tick=1336, channel=1, data=[55, 127])
# midi.NoteOffEvent(tick=1536, channel=1, data=[64, 127])
# midi.NoteOffEvent(tick=1536, channel=1, data=[59, 127])
# midi.NoteOffEvent(tick=1536, channel=1, data=[55, 127])
# midi.NoteOnEvent(tick=1536, channel=1, data=[64, 127])
# midi.NoteOnEvent(tick=1536, channel=1, data=[59, 127])
# midi.NoteOnEvent(tick=1536, channel=1, data=[55, 127])
# midi.NoteOffEvent(tick=1724, channel=1, data=[64, 127])
# midi.NoteOffEvent(tick=1724, channel=1, data=[59, 127])
# midi.NoteOffEvent(tick=1724, channel=1, data=[55, 127])
# midi.NoteOnEvent(tick=1724, channel=1, data=[64, 127])
# midi.NoteOnEvent(tick=1724, channel=1, data=[59, 127])
# midi.NoteOnEvent(tick=1724, channel=1, data=[55, 127])
# midi.NoteOffEvent(tick=1920, channel=1, data=[64, 127])
# midi.NoteOffEvent(tick=1920, channel=1, data=[59, 127])
# midi.NoteOffEvent(tick=1920, channel=1, data=[55, 127])
# midi.NoteOnEvent(tick=1920, channel=1, data=[64, 127])
# midi.NoteOnEvent(tick=1920, channel=1, data=[57, 127])
# midi.NoteOnEvent(tick=1920, channel=1, data=[54, 127])
# midi.NoteOffEvent(tick=2132, channel=1, data=[64, 127])
# midi.NoteOffEvent(tick=2132, channel=1, data=[57, 127])
# midi.NoteOffEvent(tick=2132, channel=1, data=[54, 127])
# midi.NoteOnEvent(tick=2132, channel=1, data=[64, 127])
# midi.NoteOnEvent(tick=2132, channel=1, data=[57, 127])
# midi.NoteOnEvent(tick=2132, channel=1, data=[54, 127])
# midi.NoteOffEvent(tick=2304, channel=1, data=[64, 127])
# midi.NoteOffEvent(tick=2304, channel=1, data=[57, 127])
# midi.NoteOffEvent(tick=2304, channel=1, data=[54, 127])
# midi.NoteOnEvent(tick=2304, channel=1, data=[64, 127])
# midi.NoteOnEvent(tick=2304, channel=1, data=[57, 127])
# midi.NoteOnEvent(tick=2304, channel=1, data=[54, 127])
# midi.NoteOffEvent(tick=2484, channel=1, data=[64, 127])
# midi.NoteOffEvent(tick=2484, channel=1, data=[57, 127])
# midi.NoteOffEvent(tick=2484, channel=1, data=[54, 127])
# midi.NoteOnEvent(tick=2484, channel=1, data=[64, 127])
# midi.NoteOnEvent(tick=2484, channel=1, data=[57, 127])
# midi.NoteOnEvent(tick=2484, channel=1, data=[54, 127])
# midi.NoteOffEvent(tick=2688, channel=1, data=[64, 127])
# midi.NoteOffEvent(tick=2688, channel=1, data=[57, 127])
# midi.NoteOffEvent(tick=2688, channel=1, data=[54, 127])
# midi.NoteOnEvent(tick=2688, channel=1, data=[63, 127])
# midi.NoteOnEvent(tick=2688, channel=1, data=[57, 127])
# midi.NoteOnEvent(tick=2688, channel=1, data=[54, 127])
# midi.NoteOffEvent(tick=2902, channel=1, data=[63, 127])
# midi.NoteOffEvent(tick=2902, channel=1, data=[57, 127])
# midi.NoteOffEvent(tick=2902, channel=1, data=[54, 127])
# midi.NoteOnEvent(tick=2902, channel=1, data=[63, 127])
# midi.NoteOnEvent(tick=2902, channel=1, data=[57, 127])
# midi.NoteOnEvent(tick=2902, channel=1, data=[54, 127])
# midi.NoteOffEvent(tick=3072, channel=1, data=[63, 127])
# midi.NoteOffEvent(tick=3072, channel=1, data=[57, 127])
# midi.NoteOffEvent(tick=3072, channel=1, data=[54, 127])
# midi.NoteOnEvent(tick=3072, channel=1, data=[63, 127])
# midi.NoteOnEvent(tick=3072, channel=1, data=[57, 127])
# midi.NoteOnEvent(tick=3072, channel=1, data=[54, 127])
# midi.NoteOffEvent(tick=3238, channel=1, data=[63, 127])
# midi.NoteOffEvent(tick=3238, channel=1, data=[57, 127])
# midi.NoteOffEvent(tick=3238, channel=1, data=[54, 127])
# midi.NoteOnEvent(tick=3238, channel=1, data=[63, 127])
# midi.NoteOnEvent(tick=3238, channel=1, data=[57, 127])
# midi.NoteOnEvent(tick=3238, channel=1, data=[54, 127])
# midi.NoteOffEvent(tick=3456, channel=1, data=[63, 127])
# midi.NoteOffEvent(tick=3456, channel=1, data=[57, 127])
# midi.NoteOffEvent(tick=3456, channel=1, data=[54, 127])
# midi.NoteOnEvent(tick=3456, channel=1, data=[63, 127])
# midi.NoteOnEvent(tick=3456, channel=1, data=[57, 127])
# midi.NoteOnEvent(tick=3456, channel=1, data=[53, 127])
# midi.NoteOffEvent(tick=3678, channel=1, data=[63, 127])
# midi.NoteOffEvent(tick=3678, channel=1, data=[57, 127])
# midi.NoteOffEvent(tick=3678, channel=1, data=[53, 127])
# midi.NoteOnEvent(tick=3678, channel=1, data=[63, 127])
# midi.NoteOnEvent(tick=3678, channel=1, data=[57, 127])
# midi.NoteOnEvent(tick=3678, channel=1, data=[53, 127])
# midi.NoteOffEvent(tick=3840, channel=1, data=[63, 127])
# midi.NoteOffEvent(tick=3840, channel=1, data=[57, 127])
# midi.NoteOffEvent(tick=3840, channel=1, data=[53, 127])
# midi.NoteOnEvent(tick=3840, channel=1, data=[63, 127])
# midi.NoteOnEvent(tick=3840, channel=1, data=[57, 127])
# midi.NoteOnEvent(tick=3840, channel=1, data=[53, 127])
# midi.NoteOffEvent(tick=4036, channel=1, data=[63, 127])
# midi.NoteOffEvent(tick=4036, channel=1, data=[57, 127])
# midi.NoteOffEvent(tick=4036, channel=1, data=[53, 127])
# midi.NoteOnEvent(tick=4036, channel=1, data=[63, 127])
# midi.NoteOnEvent(tick=4036, channel=1, data=[57, 127])
# midi.NoteOnEvent(tick=4036, channel=1, data=[53, 127])
# midi.NoteOffEvent(tick=4224, channel=1, data=[63, 127])
# midi.NoteOffEvent(tick=4224, channel=1, data=[57, 127])
# midi.NoteOffEvent(tick=4224, channel=1, data=[53, 127])
# midi.NoteOnEvent(tick=4224, channel=1, data=[62, 127])
# midi.NoteOnEvent(tick=4224, channel=1, data=[57, 127])
# midi.NoteOnEvent(tick=4224, channel=1, data=[53, 127])
# midi.NoteOffEvent(tick=4410, channel=1, data=[62, 127])
# midi.NoteOffEvent(tick=4410, channel=1, data=[57, 127])
# midi.NoteOffEvent(tick=4410, channel=1, data=[53, 127])
# midi.NoteOnEvent(tick=4410, channel=1, data=[62, 127])
# midi.NoteOnEvent(tick=4410, channel=1, data=[57, 127])
# midi.NoteOnEvent(tick=4410, channel=1, data=[53, 127])
# midi.NoteOffEvent(tick=4608, channel=1, data=[62, 127])
# midi.NoteOffEvent(tick=4608, channel=1, data=[57, 127])
# midi.NoteOffEvent(tick=4608, channel=1, data=[53, 127])
# midi.NoteOnEvent(tick=4608, channel=1, data=[62, 127])
# midi.NoteOnEvent(tick=4608, channel=1, data=[56, 127])
# midi.NoteOnEvent(tick=4608, channel=1, data=[53, 127])
# midi.NoteOffEvent(tick=4788, channel=1, data=[62, 127])
# midi.NoteOffEvent(tick=4788, channel=1, data=[56, 127])
# midi.NoteOffEvent(tick=4788, channel=1, data=[53, 127])
# midi.NoteOnEvent(tick=4788, channel=1, data=[62, 127])
# midi.NoteOnEvent(tick=4788, channel=1, data=[56, 127])
# midi.NoteOnEvent(tick=4788, channel=1, data=[53, 127])
# midi.NoteOffEvent(tick=4992, channel=1, data=[62, 127])
# midi.NoteOffEvent(tick=4992, channel=1, data=[56, 127])
# midi.NoteOffEvent(tick=4992, channel=1, data=[53, 127])
# midi.NoteOnEvent(tick=4992, channel=1, data=[62, 127])
# midi.NoteOnEvent(tick=4992, channel=1, data=[56, 127])
# midi.NoteOnEvent(tick=4992, channel=1, data=[52, 127])
# midi.NoteOffEvent(tick=5225, channel=1, data=[62, 127])
# midi.NoteOffEvent(tick=5225, channel=1, data=[56, 127])
# midi.NoteOffEvent(tick=5225, channel=1, data=[52, 127])
# midi.NoteOnEvent(tick=5225, channel=1, data=[62, 127])
# midi.NoteOnEvent(tick=5225, channel=1, data=[56, 127])
# midi.NoteOnEvent(tick=5225, channel=1, data=[52, 127])
# midi.NoteOffEvent(tick=5376, channel=1, data=[62, 127])
# midi.NoteOffEvent(tick=5376, channel=1, data=[56, 127])
# midi.NoteOffEvent(tick=5376, channel=1, data=[52, 127])
# midi.NoteOnEvent(tick=5376, channel=1, data=[62, 127])
# midi.NoteOnEvent(tick=5376, channel=1, data=[56, 127])
# midi.NoteOnEvent(tick=5376, channel=1, data=[52, 127])
# midi.NoteOffEvent(tick=5572, channel=1, data=[62, 127])
# midi.NoteOffEvent(tick=5572, channel=1, data=[56, 127])
# midi.NoteOffEvent(tick=5572, channel=1, data=[52, 127])
# midi.NoteOnEvent(tick=5572, channel=1, data=[62, 127])
# midi.NoteOnEvent(tick=5572, channel=1, data=[56, 127])
# midi.NoteOnEvent(tick=5572, channel=1, data=[52, 127])
# midi.NoteOffEvent(tick=5760, channel=1, data=[62, 127])
# midi.NoteOffEvent(tick=5760, channel=1, data=[56, 127])
# midi.NoteOffEvent(tick=5760, channel=1, data=[52, 127])
# midi.NoteOnEvent(tick=5760, channel=1, data=[62, 127])
# midi.NoteOnEvent(tick=5760, channel=1, data=[55, 127])
# midi.NoteOnEvent(tick=5760, channel=1, data=[52, 127])
# midi.NoteOffEvent(tick=5960, channel=1, data=[62, 127])
# midi.NoteOffEvent(tick=5960, channel=1, data=[55, 127])
# midi.NoteOffEvent(tick=5960, channel=1, data=[52, 127])
# midi.NoteOnEvent(tick=5960, channel=1, data=[62, 127])
# midi.NoteOnEvent(tick=5960, channel=1, data=[55, 127])
# midi.NoteOnEvent(tick=5960, channel=1, data=[52, 127])
# midi.NoteOffEvent(tick=6144, channel=1, data=[62, 127])
# midi.NoteOffEvent(tick=6144, channel=1, data=[55, 127])
# midi.NoteOffEvent(tick=6144, channel=1, data=[52, 127])
# midi.NoteOnEvent(tick=6144, channel=1, data=[61, 127])
# midi.NoteOnEvent(tick=6144, channel=1, data=[55, 127])
# midi.NoteOnEvent(tick=6144, channel=1, data=[52, 127])
# midi.NoteOffEvent(tick=6343, channel=1, data=[61, 127])
# midi.NoteOffEvent(tick=6343, channel=1, data=[55, 127])
# midi.NoteOffEvent(tick=6343, channel=1, data=[52, 127])
# midi.NoteOnEvent(tick=6343, channel=1, data=[61, 127])
# midi.NoteOnEvent(tick=6343, channel=1, data=[55, 127])
# midi.NoteOnEvent(tick=6343, channel=1, data=[52, 127])
# midi.NoteOffEvent(tick=6528, channel=1, data=[61, 127])
# midi.NoteOffEvent(tick=6528, channel=1, data=[55, 127])
# midi.NoteOffEvent(tick=6528, channel=1, data=[52, 127])
# midi.NoteOnEvent(tick=6528, channel=1, data=[60, 127])
# midi.NoteOnEvent(tick=6528, channel=1, data=[55, 127])
# midi.NoteOnEvent(tick=6528, channel=1, data=[52, 127])
# midi.NoteOffEvent(tick=6748, channel=1, data=[60, 127])
# midi.NoteOffEvent(tick=6748, channel=1, data=[55, 127])
# midi.NoteOffEvent(tick=6748, channel=1, data=[52, 127])
# midi.NoteOnEvent(tick=6748, channel=1, data=[60, 127])
# midi.NoteOnEvent(tick=6748, channel=1, data=[55, 127])
# midi.NoteOnEvent(tick=6748, channel=1, data=[52, 127])
# midi.NoteOffEvent(tick=6912, channel=1, data=[60, 127])
# midi.NoteOffEvent(tick=6912, channel=1, data=[55, 127])
# midi.NoteOffEvent(tick=6912, channel=1, data=[52, 127])
# midi.NoteOnEvent(tick=6912, channel=1, data=[60, 127])
# midi.NoteOnEvent(tick=6912, channel=1, data=[55, 127])
# midi.NoteOnEvent(tick=6912, channel=1, data=[52, 127])
# midi.NoteOffEvent(tick=7111, channel=1, data=[60, 127])
# midi.NoteOffEvent(tick=7111, channel=1, data=[55, 127])
# midi.NoteOffEvent(tick=7111, channel=1, data=[52, 127])
# midi.NoteOnEvent(tick=7111, channel=1, data=[60, 127])
# midi.NoteOnEvent(tick=7111, channel=1, data=[55, 127])
# midi.NoteOnEvent(tick=7111, channel=1, data=[52, 127])
# midi.NoteOffEvent(tick=7296, channel=1, data=[60, 127])
# midi.NoteOffEvent(tick=7296, channel=1, data=[55, 127])
# midi.NoteOffEvent(tick=7296, channel=1, data=[52, 127])
# midi.NoteOnEvent(tick=7296, channel=1, data=[60, 127])
# midi.NoteOnEvent(tick=7296, channel=1, data=[54, 127])
# midi.NoteOnEvent(tick=7296, channel=1, data=[52, 127])
# midi.NoteOffEvent(tick=7492, channel=1, data=[60, 127])
# midi.NoteOffEvent(tick=7492, channel=1, data=[54, 127])
# midi.NoteOffEvent(tick=7492, channel=1, data=[52, 127])
# midi.NoteOnEvent(tick=7492, channel=1, data=[60, 127])
# midi.NoteOnEvent(tick=7492, channel=1, data=[54, 127])
# midi.NoteOnEvent(tick=7492, channel=1, data=[52, 127])
# midi.NoteOffEvent(tick=7680, channel=1, data=[60, 127])
# midi.NoteOffEvent(tick=7680, channel=1, data=[54, 127])
# midi.NoteOffEvent(tick=7680, channel=1, data=[52, 127])
# midi.NoteOnEvent(tick=7680, channel=1, data=[60, 127])
# midi.NoteOnEvent(tick=7680, channel=1, data=[54, 127])
# midi.NoteOnEvent(tick=7680, channel=1, data=[52, 127])
# midi.NoteOffEvent(tick=7881, channel=1, data=[60, 127])
# midi.NoteOffEvent(tick=7881, channel=1, data=[54, 127])
# midi.NoteOffEvent(tick=7881, channel=1, data=[52, 127])
# midi.NoteOnEvent(tick=7881, channel=1, data=[60, 127])
# midi.NoteOnEvent(tick=7881, channel=1, data=[54, 127])
# midi.NoteOnEvent(tick=7881, channel=1, data=[52, 127])
# midi.NoteOffEvent(tick=8064, channel=1, data=[60, 127])
# midi.NoteOffEvent(tick=8064, channel=1, data=[54, 127])
# midi.NoteOffEvent(tick=8064, channel=1, data=[52, 127])
# midi.NoteOnEvent(tick=8064, channel=1, data=[60, 127])
# midi.NoteOnEvent(tick=8064, channel=1, data=[54, 127])
# midi.NoteOnEvent(tick=8064, channel=1, data=[52, 127])
# midi.NoteOffEvent(tick=8290, channel=1, data=[60, 127])
# midi.NoteOffEvent(tick=8290, channel=1, data=[54, 127])
# midi.NoteOffEvent(tick=8290, channel=1, data=[52, 127])
# midi.NoteOnEvent(tick=8290, channel=1, data=[60, 127])
# midi.NoteOnEvent(tick=8290, channel=1, data=[54, 127])
# midi.NoteOnEvent(tick=8290, channel=1, data=[52, 127])
# midi.NoteOffEvent(tick=8448, channel=1, data=[60, 127])
# midi.NoteOffEvent(tick=8448, channel=1, data=[54, 127])
# midi.NoteOffEvent(tick=8448, channel=1, data=[52, 127])
# midi.NoteOnEvent(tick=8448, channel=1, data=[60, 127])
# midi.NoteOnEvent(tick=8448, channel=1, data=[54, 127])
# midi.NoteOnEvent(tick=8448, channel=1, data=[52, 127])
# midi.NoteOffEvent(tick=8622, channel=1, data=[60, 127])
# midi.NoteOffEvent(tick=8622, channel=1, data=[54, 127])
# midi.NoteOffEvent(tick=8622, channel=1, data=[52, 127])
# midi.NoteOnEvent(tick=8622, channel=1, data=[60, 127])
# midi.NoteOnEvent(tick=8622, channel=1, data=[54, 127])
# midi.NoteOnEvent(tick=8622, channel=1, data=[52, 127])
# midi.NoteOffEvent(tick=8832, channel=1, data=[60, 127])
# midi.NoteOffEvent(tick=8832, channel=1, data=[54, 127])
# midi.NoteOffEvent(tick=8832, channel=1, data=[52, 127])
# midi.NoteOnEvent(tick=8832, channel=1, data=[60, 127])
# midi.NoteOnEvent(tick=8832, channel=1, data=[54, 127])
# midi.NoteOnEvent(tick=8832, channel=1, data=[51, 127])
# midi.NoteOffEvent(tick=9033, channel=1, data=[60, 127])
# midi.NoteOffEvent(tick=9033, channel=1, data=[54, 127])
# midi.NoteOffEvent(tick=9033, channel=1, data=[51, 127])
# midi.NoteOnEvent(tick=9033, channel=1, data=[60, 127])
# midi.NoteOnEvent(tick=9033, channel=1, data=[54, 127])
# midi.NoteOnEvent(tick=9033, channel=1, data=[51, 127])
# midi.NoteOffEvent(tick=9216, channel=1, data=[60, 127])
# midi.NoteOffEvent(tick=9216, channel=1, data=[54, 127])
# midi.NoteOffEvent(tick=9216, channel=1, data=[51, 127])
# midi.NoteOnEvent(tick=9216, channel=1, data=[60, 127])
# midi.NoteOnEvent(tick=9216, channel=1, data=[54, 127])
# midi.NoteOnEvent(tick=9216, channel=1, data=[51, 127])
# midi.NoteOffEvent(tick=9397, channel=1, data=[60, 127])
# midi.NoteOffEvent(tick=9397, channel=1, data=[54, 127])
# midi.NoteOffEvent(tick=9397, channel=1, data=[51, 127])
# midi.NoteOnEvent(tick=9397, channel=1, data=[60, 127])
# midi.NoteOnEvent(tick=9397, channel=1, data=[54, 127])
# midi.NoteOnEvent(tick=9397, channel=1, data=[51, 127])
# midi.NoteOffEvent(tick=9600, channel=1, data=[60, 127])
# midi.NoteOffEvent(tick=9600, channel=1, data=[54, 127])
# midi.NoteOffEvent(tick=9600, channel=1, data=[51, 127])
# midi.NoteOnEvent(tick=9600, channel=1, data=[60, 127])
# midi.NoteOnEvent(tick=9600, channel=1, data=[54, 127])
# midi.NoteOnEvent(tick=9600, channel=1, data=[50, 127])
# midi.NoteOffEvent(tick=9827, channel=1, data=[60, 127])
# midi.NoteOffEvent(tick=9827, channel=1, data=[54, 127])
# midi.NoteOffEvent(tick=9827, channel=1, data=[50, 127])
# midi.NoteOnEvent(tick=9827, channel=1, data=[60, 127])
# midi.NoteOnEvent(tick=9827, channel=1, data=[54, 127])
# midi.NoteOnEvent(tick=9827, channel=1, data=[50, 127])
# midi.NoteOffEvent(tick=9984, channel=1, data=[60, 127])
# midi.NoteOffEvent(tick=9984, channel=1, data=[54, 127])
# midi.NoteOffEvent(tick=9984, channel=1, data=[50, 127])
# midi.NoteOnEvent(tick=9984, channel=1, data=[60, 127])
# midi.NoteOnEvent(tick=9984, channel=1, data=[54, 127])
# midi.NoteOnEvent(tick=9984, channel=1, data=[50, 127])
# midi.NoteOffEvent(tick=10164, channel=1, data=[60, 127])
# midi.NoteOffEvent(tick=10164, channel=1, data=[54, 127])
# midi.NoteOffEvent(tick=10164, channel=1, data=[50, 127])
# midi.NoteOnEvent(tick=10164, channel=1, data=[60, 127])
# midi.NoteOnEvent(tick=10164, channel=1, data=[54, 127])
# midi.NoteOnEvent(tick=10164, channel=1, data=[50, 127])
# midi.NoteOffEvent(tick=10368, channel=1, data=[60, 127])
# midi.NoteOffEvent(tick=10368, channel=1, data=[54, 127])
# midi.NoteOffEvent(tick=10368, channel=1, data=[50, 127])
# midi.NoteOnEvent(tick=10368, channel=1, data=[60, 127])
# midi.NoteOnEvent(tick=10368, channel=1, data=[54, 127])
# midi.NoteOnEvent(tick=10368, channel=1, data=[50, 127])
# midi.NoteOffEvent(tick=10554, channel=1, data=[60, 127])
# midi.NoteOffEvent(tick=10554, channel=1, data=[54, 127])
# midi.NoteOffEvent(tick=10554, channel=1, data=[50, 127])
# midi.NoteOnEvent(tick=10554, channel=1, data=[60, 127])
# midi.NoteOnEvent(tick=10554, channel=1, data=[54, 127])
# midi.NoteOnEvent(tick=10554, channel=1, data=[50, 127])
# midi.NoteOffEvent(tick=10752, channel=1, data=[60, 127])
# midi.NoteOffEvent(tick=10752, channel=1, data=[54, 127])
# midi.NoteOffEvent(tick=10752, channel=1, data=[50, 127])
# midi.NoteOnEvent(tick=10752, channel=1, data=[60, 127])
# midi.NoteOnEvent(tick=10752, channel=1, data=[54, 127])
# midi.NoteOnEvent(tick=10752, channel=1, data=[50, 127])
# midi.NoteOffEvent(tick=10935, channel=1, data=[60, 127])
# midi.NoteOffEvent(tick=10935, channel=1, data=[54, 127])
# midi.NoteOffEvent(tick=10935, channel=1, data=[50, 127])
# midi.NoteOnEvent(tick=10935, channel=1, data=[60, 127])
# midi.NoteOnEvent(tick=10935, channel=1, data=[54, 127])
# midi.NoteOnEvent(tick=10935, channel=1, data=[50, 127])
# midi.NoteOffEvent(tick=11136, channel=1, data=[60, 127])
# midi.NoteOffEvent(tick=11136, channel=1, data=[54, 127])
# midi.NoteOffEvent(tick=11136, channel=1, data=[50, 127])
# midi.NoteOnEvent(tick=11136, channel=1, data=[60, 127])
# midi.NoteOnEvent(tick=11136, channel=1, data=[53, 127])
# midi.NoteOnEvent(tick=11136, channel=1, data=[50, 127])
# midi.NoteOffEvent(tick=11354, channel=1, data=[60, 127])
# midi.NoteOffEvent(tick=11354, channel=1, data=[53, 127])
# midi.NoteOffEvent(tick=11354, channel=1, data=[50, 127])
# midi.NoteOnEvent(tick=11354, channel=1, data=[60, 127])
# midi.NoteOnEvent(tick=11354, channel=1, data=[53, 127])
# midi.NoteOnEvent(tick=11354, channel=1, data=[50, 127])
# midi.NoteOffEvent(tick=11520, channel=1, data=[60, 127])
# midi.NoteOffEvent(tick=11520, channel=1, data=[53, 127])
# midi.NoteOffEvent(tick=11520, channel=1, data=[50, 127])
# midi.NoteOnEvent(tick=11520, channel=1, data=[60, 127])
# midi.NoteOnEvent(tick=11520, channel=1, data=[53, 127])
# midi.NoteOnEvent(tick=11520, channel=1, data=[50, 127])
# midi.NoteOffEvent(tick=11712, channel=1, data=[60, 127])
# midi.NoteOffEvent(tick=11712, channel=1, data=[53, 127])
# midi.NoteOffEvent(tick=11712, channel=1, data=[50, 127])
# midi.NoteOnEvent(tick=11712, channel=1, data=[60, 127])
# midi.NoteOnEvent(tick=11712, channel=1, data=[53, 127])
# midi.NoteOnEvent(tick=11712, channel=1, data=[50, 127])
# midi.NoteOffEvent(tick=11904, channel=1, data=[60, 127])
# midi.NoteOffEvent(tick=11904, channel=1, data=[53, 127])
# midi.NoteOffEvent(tick=11904, channel=1, data=[50, 127])
# midi.NoteOnEvent(tick=11904, channel=1, data=[59, 127])
# midi.NoteOnEvent(tick=11904, channel=1, data=[53, 127])
# midi.NoteOnEvent(tick=11904, channel=1, data=[50, 127])
# midi.NoteOffEvent(tick=12107, channel=1, data=[59, 127])
# midi.NoteOffEvent(tick=12107, channel=1, data=[53, 127])
# midi.NoteOffEvent(tick=12107, channel=1, data=[50, 127])
# midi.NoteOnEvent(tick=12107, channel=1, data=[59, 127])
# midi.NoteOnEvent(tick=12107, channel=1, data=[53, 127])
# midi.NoteOnEvent(tick=12107, channel=1, data=[50, 127])
# midi.NoteOffEvent(tick=12288, channel=1, data=[59, 127])
# midi.NoteOffEvent(tick=12288, channel=1, data=[53, 127])
# midi.NoteOffEvent(tick=12288, channel=1, data=[50, 127])
# midi.NoteOnEvent(tick=12288, channel=1, data=[59, 127])
# midi.NoteOnEvent(tick=12288, channel=1, data=[53, 127])
# midi.NoteOnEvent(tick=12288, channel=1, data=[50, 127])
# midi.NoteOffEvent(tick=12460, channel=1, data=[59, 127])
# midi.NoteOffEvent(tick=12460, channel=1, data=[53, 127])
# midi.NoteOffEvent(tick=12460, channel=1, data=[50, 127])
# midi.NoteOnEvent(tick=12460, channel=1, data=[59, 127])
# midi.NoteOnEvent(tick=12460, channel=1, data=[53, 127])
# midi.NoteOnEvent(tick=12460, channel=1, data=[50, 127])
# midi.NoteOffEvent(tick=12672, channel=1, data=[59, 127])
# midi.NoteOffEvent(tick=12672, channel=1, data=[53, 127])
# midi.NoteOffEvent(tick=12672, channel=1, data=[50, 127])
# midi.NoteOnEvent(tick=12672, channel=1, data=[59, 127])
# midi.NoteOnEvent(tick=12672, channel=1, data=[52, 127])
# midi.NoteOnEvent(tick=12672, channel=1, data=[48, 127])
# midi.NoteOffEvent(tick=12855, channel=1, data=[59, 127])
# midi.NoteOffEvent(tick=12855, channel=1, data=[52, 127])
# midi.NoteOffEvent(tick=12855, channel=1, data=[48, 127])
# midi.NoteOnEvent(tick=12855, channel=1, data=[59, 127])
# midi.NoteOnEvent(tick=12855, channel=1, data=[52, 127])
# midi.NoteOnEvent(tick=12855, channel=1, data=[48, 127])
# midi.NoteOffEvent(tick=13056, channel=1, data=[59, 127])
# midi.NoteOffEvent(tick=13056, channel=1, data=[52, 127])
# midi.NoteOffEvent(tick=13056, channel=1, data=[48, 127])
# midi.NoteOnEvent(tick=13056, channel=1, data=[57, 127])
# midi.NoteOnEvent(tick=13056, channel=1, data=[52, 127])
# midi.NoteOnEvent(tick=13056, channel=1, data=[48, 127])
# midi.NoteOffEvent(tick=13263, channel=1, data=[57, 127])
# midi.NoteOffEvent(tick=13263, channel=1, data=[52, 127])
# midi.NoteOffEvent(tick=13263, channel=1, data=[48, 127])
# midi.NoteOnEvent(tick=13263, channel=1, data=[57, 127])
# midi.NoteOnEvent(tick=13263, channel=1, data=[52, 127])
# midi.NoteOnEvent(tick=13263, channel=1, data=[48, 127])
# midi.NoteOffEvent(tick=13440, channel=1, data=[57, 127])
# midi.NoteOffEvent(tick=13440, channel=1, data=[52, 127])
# midi.NoteOffEvent(tick=13440, channel=1, data=[48, 127])
# midi.NoteOnEvent(tick=13440, channel=1, data=[57, 127])
# midi.NoteOnEvent(tick=13440, channel=1, data=[52, 127])
# midi.NoteOnEvent(tick=13440, channel=1, data=[48, 127])
# midi.NoteOffEvent(tick=13628, channel=1, data=[57, 127])
# midi.NoteOffEvent(tick=13628, channel=1, data=[52, 127])
# midi.NoteOffEvent(tick=13628, channel=1, data=[48, 127])
# midi.NoteOnEvent(tick=13628, channel=1, data=[57, 127])
# midi.NoteOnEvent(tick=13628, channel=1, data=[52, 127])
# midi.NoteOnEvent(tick=13628, channel=1, data=[48, 127])
# midi.NoteOffEvent(tick=13824, channel=1, data=[57, 127])
# midi.NoteOffEvent(tick=13824, channel=1, data=[52, 127])
# midi.NoteOffEvent(tick=13824, channel=1, data=[48, 127])
# midi.NoteOnEvent(tick=13824, channel=1, data=[57, 127])
# midi.NoteOnEvent(tick=13824, channel=1, data=[52, 127])
# midi.NoteOnEvent(tick=13824, channel=1, data=[48, 127])
# midi.NoteOffEvent(tick=14003, channel=1, data=[57, 127])
# midi.NoteOffEvent(tick=14003, channel=1, data=[52, 127])
# midi.NoteOffEvent(tick=14003, channel=1, data=[48, 127])
# midi.NoteOnEvent(tick=14003, channel=1, data=[57, 127])
# midi.NoteOnEvent(tick=14003, channel=1, data=[52, 127])
# midi.NoteOnEvent(tick=14003, channel=1, data=[48, 127])
# midi.NoteOffEvent(tick=14208, channel=1, data=[57, 127])
# midi.NoteOffEvent(tick=14208, channel=1, data=[52, 127])
# midi.NoteOffEvent(tick=14208, channel=1, data=[48, 127])
# midi.NoteOnEvent(tick=14208, channel=1, data=[57, 127])
# midi.NoteOnEvent(tick=14208, channel=1, data=[52, 127])
# midi.NoteOnEvent(tick=14208, channel=1, data=[47, 127])
# midi.NoteOffEvent(tick=14427, channel=1, data=[57, 127])
# midi.NoteOffEvent(tick=14427, channel=1, data=[52, 127])
# midi.NoteOffEvent(tick=14427, channel=1, data=[47, 127])
# midi.NoteOnEvent(tick=14427, channel=1, data=[57, 127])
# midi.NoteOnEvent(tick=14427, channel=1, data=[52, 127])
# midi.NoteOnEvent(tick=14427, channel=1, data=[47, 127])
# midi.NoteOffEvent(tick=14592, channel=1, data=[57, 127])
# midi.NoteOffEvent(tick=14592, channel=1, data=[52, 127])
# midi.NoteOffEvent(tick=14592, channel=1, data=[47, 127])
# midi.NoteOnEvent(tick=14592, channel=1, data=[57, 127])
# midi.NoteOnEvent(tick=14592, channel=1, data=[51, 127])
# midi.NoteOnEvent(tick=14592, channel=1, data=[47, 127])
# midi.NoteOffEvent(tick=14782, channel=1, data=[57, 127])
# midi.NoteOffEvent(tick=14782, channel=1, data=[51, 127])
# midi.NoteOffEvent(tick=14782, channel=1, data=[47, 127])
# midi.NoteOnEvent(tick=14782, channel=1, data=[57, 127])
# midi.NoteOnEvent(tick=14782, channel=1, data=[51, 127])
# midi.NoteOnEvent(tick=14782, channel=1, data=[47, 127])
# midi.NoteOffEvent(tick=14976, channel=1, data=[57, 127])
# midi.NoteOffEvent(tick=14976, channel=1, data=[51, 127])
# midi.NoteOffEvent(tick=14976, channel=1, data=[47, 127])
# midi.NoteOnEvent(tick=14976, channel=1, data=[57, 127])
# midi.NoteOnEvent(tick=14976, channel=1, data=[52, 127])
# midi.NoteOnEvent(tick=14976, channel=1, data=[48, 127])
# midi.NoteOffEvent(tick=15174, channel=1, data=[57, 127])
# midi.NoteOffEvent(tick=15174, channel=1, data=[52, 127])
# midi.NoteOffEvent(tick=15174, channel=1, data=[48, 127])
# midi.NoteOnEvent(tick=15174, channel=1, data=[57, 127])
# midi.NoteOnEvent(tick=15174, channel=1, data=[52, 127])
# midi.NoteOnEvent(tick=15174, channel=1, data=[48, 127])
# midi.NoteOffEvent(tick=15360, channel=1, data=[57, 127])
# midi.NoteOffEvent(tick=15360, channel=1, data=[52, 127])
# midi.NoteOffEvent(tick=15360, channel=1, data=[48, 127])
# midi.NoteOnEvent(tick=15360, channel=1, data=[57, 127])
# midi.NoteOnEvent(tick=15360, channel=1, data=[52, 127])
# midi.NoteOnEvent(tick=15360, channel=1, data=[48, 127])
# midi.NoteOffEvent(tick=15537, channel=1, data=[57, 127])
# midi.NoteOffEvent(tick=15537, channel=1, data=[52, 127])
# midi.NoteOffEvent(tick=15537, channel=1, data=[48, 127])
# midi.NoteOnEvent(tick=15537, channel=1, data=[57, 127])
# midi.NoteOnEvent(tick=15537, channel=1, data=[52, 127])
# midi.NoteOnEvent(tick=15537, channel=1, data=[48, 127])
# midi.NoteOffEvent(tick=15744, channel=1, data=[57, 127])
# midi.NoteOffEvent(tick=15744, channel=1, data=[52, 127])
# midi.NoteOffEvent(tick=15744, channel=1, data=[48, 127])
# midi.NoteOnEvent(tick=15744, channel=1, data=[57, 127])
# midi.NoteOnEvent(tick=15744, channel=1, data=[51, 127])
# midi.NoteOnEvent(tick=15744, channel=1, data=[47, 127])
# midi.NoteOffEvent(tick=15956, channel=1, data=[57, 127])
# midi.NoteOffEvent(tick=15956, channel=1, data=[51, 127])
# midi.NoteOffEvent(tick=15956, channel=1, data=[47, 127])
# midi.NoteOnEvent(tick=15956, channel=1, data=[57, 127])
# midi.NoteOnEvent(tick=15956, channel=1, data=[51, 127])
# midi.NoteOnEvent(tick=15956, channel=1, data=[47, 127])
# midi.NoteOffEvent(tick=16128, channel=1, data=[57, 127])
# midi.NoteOffEvent(tick=16128, channel=1, data=[51, 127])
# midi.NoteOffEvent(tick=16128, channel=1, data=[47, 127])
# midi.NoteOnEvent(tick=16128, channel=1, data=[57, 127])
# midi.NoteOnEvent(tick=16128, channel=1, data=[51, 127])
# midi.NoteOnEvent(tick=16128, channel=1, data=[47, 127])
# midi.NoteOffEvent(tick=16317, channel=1, data=[57, 127])
# midi.NoteOffEvent(tick=16317, channel=1, data=[51, 127])
# midi.NoteOffEvent(tick=16317, channel=1, data=[47, 127])
# midi.NoteOnEvent(tick=16317, channel=1, data=[57, 127])
# midi.NoteOnEvent(tick=16317, channel=1, data=[51, 127])
# midi.NoteOnEvent(tick=16317, channel=1, data=[47, 127])
# midi.NoteOffEvent(tick=16512, channel=1, data=[57, 127])
# midi.NoteOffEvent(tick=16512, channel=1, data=[51, 127])
# midi.NoteOffEvent(tick=16512, channel=1, data=[47, 127])
# midi.NoteOnEvent(tick=16512, channel=1, data=[57, 127])
# midi.NoteOnEvent(tick=16512, channel=1, data=[52, 127])
# midi.NoteOnEvent(tick=16512, channel=1, data=[48, 127])
# midi.NoteOffEvent(tick=16653, channel=1, data=[57, 127])
# midi.NoteOffEvent(tick=16653, channel=1, data=[52, 127])
# midi.NoteOffEvent(tick=16653, channel=1, data=[48, 127])
# midi.NoteOnEvent(tick=16653, channel=1, data=[57, 127])
# midi.NoteOnEvent(tick=16653, channel=1, data=[52, 127])
# midi.NoteOnEvent(tick=16653, channel=1, data=[48, 127])
# midi.NoteOffEvent(tick=16896, channel=1, data=[57, 127])
# midi.NoteOffEvent(tick=16896, channel=1, data=[52, 127])
# midi.NoteOffEvent(tick=16896, channel=1, data=[48, 127])
# midi.NoteOnEvent(tick=16896, channel=1, data=[57, 127])
# midi.NoteOnEvent(tick=16896, channel=1, data=[52, 127])
# midi.NoteOnEvent(tick=16896, channel=1, data=[48, 127])
# midi.NoteOffEvent(tick=17121, channel=1, data=[57, 127])
# midi.NoteOffEvent(tick=17121, channel=1, data=[52, 127])
# midi.NoteOffEvent(tick=17121, channel=1, data=[48, 127])
# midi.NoteOnEvent(tick=17121, channel=1, data=[57, 127])
# midi.NoteOnEvent(tick=17121, channel=1, data=[52, 127])
# midi.NoteOnEvent(tick=17121, channel=1, data=[48, 127])
# midi.NoteOffEvent(tick=17280, channel=1, data=[57, 127])
# midi.NoteOffEvent(tick=17280, channel=1, data=[52, 127])
# midi.NoteOffEvent(tick=17280, channel=1, data=[48, 127])
# midi.NoteOnEvent(tick=17280, channel=1, data=[57, 127])
# midi.NoteOnEvent(tick=17280, channel=1, data=[51, 127])
# midi.NoteOnEvent(tick=17280, channel=1, data=[47, 127])
# midi.NoteOffEvent(tick=17664, channel=1, data=[57, 127])
# midi.NoteOffEvent(tick=17664, channel=1, data=[51, 127])
# midi.NoteOffEvent(tick=17664, channel=1, data=[47, 127])
# midi.NoteOnEvent(tick=18816, channel=1, data=[64, 127])
# midi.NoteOnEvent(tick=18816, channel=1, data=[59, 127])
# midi.NoteOnEvent(tick=18816, channel=1, data=[55, 127])
# midi.NoteOffEvent(tick=19037, channel=1, data=[64, 127])
# midi.NoteOffEvent(tick=19037, channel=1, data=[59, 127])
# midi.NoteOffEvent(tick=19037, channel=1, data=[55, 127])
# midi.NoteOnEvent(tick=19037, channel=1, data=[64, 127])
# midi.NoteOnEvent(tick=19037, channel=1, data=[59, 127])
# midi.NoteOnEvent(tick=19037, channel=1, data=[55, 127])
# midi.NoteOffEvent(tick=19200, channel=1, data=[64, 127])
# midi.NoteOffEvent(tick=19200, channel=1, data=[59, 127])
# midi.NoteOffEvent(tick=19200, channel=1, data=[55, 127])
# midi.NoteOnEvent(tick=19200, channel=1, data=[64, 127])
# midi.NoteOnEvent(tick=19200, channel=1, data=[59, 127])
# midi.NoteOnEvent(tick=19200, channel=1, data=[55, 127])
# midi.NoteOffEvent(tick=19400, channel=1, data=[64, 127])
# midi.NoteOffEvent(tick=19400, channel=1, data=[59, 127])
# midi.NoteOffEvent(tick=19400, channel=1, data=[55, 127])
# midi.NoteOnEvent(tick=19400, channel=1, data=[64, 127])
# midi.NoteOnEvent(tick=19400, channel=1, data=[59, 127])
# midi.NoteOnEvent(tick=19400, channel=1, data=[55, 127])
# midi.NoteOffEvent(tick=19584, channel=1, data=[64, 127])
# midi.NoteOffEvent(tick=19584, channel=1, data=[59, 127])
# midi.NoteOffEvent(tick=19584, channel=1, data=[55, 127])
# midi.NoteOnEvent(tick=19584, channel=1, data=[64, 127])
# midi.NoteOnEvent(tick=19584, channel=1, data=[59, 127])
# midi.NoteOnEvent(tick=19584, channel=1, data=[55, 127])
# midi.NoteOffEvent(tick=19780, channel=1, data=[64, 127])
# midi.NoteOffEvent(tick=19780, channel=1, data=[59, 127])
# midi.NoteOffEvent(tick=19780, channel=1, data=[55, 127])
# midi.NoteOnEvent(tick=19780, channel=1, data=[64, 127])
# midi.NoteOnEvent(tick=19780, channel=1, data=[59, 127])
# midi.NoteOnEvent(tick=19780, channel=1, data=[55, 127])
# midi.NoteOffEvent(tick=19968, channel=1, data=[64, 127])
# midi.NoteOffEvent(tick=19968, channel=1, data=[59, 127])
# midi.NoteOffEvent(tick=19968, channel=1, data=[55, 127])
# midi.NoteOnEvent(tick=19968, channel=1, data=[64, 127])
# midi.NoteOnEvent(tick=19968, channel=1, data=[59, 127])
# midi.NoteOnEvent(tick=19968, channel=1, data=[55, 127])
# midi.NoteOffEvent(tick=20146, channel=1, data=[64, 127])
# midi.NoteOffEvent(tick=20146, channel=1, data=[59, 127])
# midi.NoteOffEvent(tick=20146, channel=1, data=[55, 127])
# midi.NoteOnEvent(tick=20146, channel=1, data=[64, 127])
# midi.NoteOnEvent(tick=20146, channel=1, data=[59, 127])
# midi.NoteOnEvent(tick=20146, channel=1, data=[55, 127])
# midi.NoteOffEvent(tick=20352, channel=1, data=[64, 127])
# midi.NoteOffEvent(tick=20352, channel=1, data=[59, 127])
# midi.NoteOffEvent(tick=20352, channel=1, data=[55, 127])
# midi.NoteOnEvent(tick=20352, channel=1, data=[64, 127])
# midi.NoteOnEvent(tick=20352, channel=1, data=[57, 127])
# midi.NoteOnEvent(tick=20352, channel=1, data=[54, 127])
# midi.NoteOffEvent(tick=20577, channel=1, data=[64, 127])
# midi.NoteOffEvent(tick=20577, channel=1, data=[57, 127])
# midi.NoteOffEvent(tick=20577, channel=1, data=[54, 127])
# midi.NoteOnEvent(tick=20577, channel=1, data=[64, 127])
# midi.NoteOnEvent(tick=20577, channel=1, data=[57, 127])
# midi.NoteOnEvent(tick=20577, channel=1, data=[54, 127])
# midi.NoteOffEvent(tick=20736, channel=1, data=[64, 127])
# midi.NoteOffEvent(tick=20736, channel=1, data=[57, 127])
# midi.NoteOffEvent(tick=20736, channel=1, data=[54, 127])
# midi.NoteOnEvent(tick=20736, channel=1, data=[64, 127])
# midi.NoteOnEvent(tick=20736, channel=1, data=[57, 127])
# midi.NoteOnEvent(tick=20736, channel=1, data=[54, 127])
# midi.NoteOffEvent(tick=20915, channel=1, data=[64, 127])
# midi.NoteOffEvent(tick=20915, channel=1, data=[57, 127])
# midi.NoteOffEvent(tick=20915, channel=1, data=[54, 127])
# midi.NoteOnEvent(tick=20915, channel=1, data=[64, 127])
# midi.NoteOnEvent(tick=20915, channel=1, data=[57, 127])
# midi.NoteOnEvent(tick=20915, channel=1, data=[54, 127])
# midi.NoteOffEvent(tick=21120, channel=1, data=[64, 127])
# midi.NoteOffEvent(tick=21120, channel=1, data=[57, 127])
# midi.NoteOffEvent(tick=21120, channel=1, data=[54, 127])
# midi.NoteOnEvent(tick=21120, channel=1, data=[63, 127])
# midi.NoteOnEvent(tick=21120, channel=1, data=[57, 127])
# midi.NoteOnEvent(tick=21120, channel=1, data=[53, 127])
# midi.NoteOffEvent(tick=21328, channel=1, data=[63, 127])
# midi.NoteOffEvent(tick=21328, channel=1, data=[57, 127])
# midi.NoteOffEvent(tick=21328, channel=1, data=[53, 127])
# midi.NoteOnEvent(tick=21328, channel=1, data=[63, 127])
# midi.NoteOnEvent(tick=21328, channel=1, data=[57, 127])
# midi.NoteOnEvent(tick=21328, channel=1, data=[53, 127])
# midi.NoteOffEvent(tick=21504, channel=1, data=[63, 127])
# midi.NoteOffEvent(tick=21504, channel=1, data=[57, 127])
# midi.NoteOffEvent(tick=21504, channel=1, data=[53, 127])
# midi.NoteOnEvent(tick=21504, channel=1, data=[63, 127])
# midi.NoteOnEvent(tick=21504, channel=1, data=[57, 127])
# midi.NoteOnEvent(tick=21504, channel=1, data=[53, 127])
# midi.NoteOffEvent(tick=21678, channel=1, data=[63, 127])
# midi.NoteOffEvent(tick=21678, channel=1, data=[57, 127])
# midi.NoteOffEvent(tick=21678, channel=1, data=[53, 127])
# midi.NoteOnEvent(tick=21678, channel=1, data=[63, 127])
# midi.NoteOnEvent(tick=21678, channel=1, data=[57, 127])
# midi.NoteOnEvent(tick=21678, channel=1, data=[53, 127])
# midi.NoteOffEvent(tick=21888, channel=1, data=[63, 127])
# midi.NoteOffEvent(tick=21888, channel=1, data=[57, 127])
# midi.NoteOffEvent(tick=21888, channel=1, data=[53, 127])
# midi.NoteOnEvent(tick=21888, channel=1, data=[63, 127])
# midi.NoteOnEvent(tick=21888, channel=1, data=[56, 127])
# midi.NoteOnEvent(tick=21888, channel=1, data=[53, 127])
# midi.NoteOffEvent(tick=22097, channel=1, data=[63, 127])
# midi.NoteOffEvent(tick=22097, channel=1, data=[56, 127])
# midi.NoteOffEvent(tick=22097, channel=1, data=[53, 127])
# midi.NoteOnEvent(tick=22097, channel=1, data=[63, 127])
# midi.NoteOnEvent(tick=22097, channel=1, data=[56, 127])
# midi.NoteOnEvent(tick=22097, channel=1, data=[53, 127])
# midi.NoteOffEvent(tick=22272, channel=1, data=[63, 127])
# midi.NoteOffEvent(tick=22272, channel=1, data=[56, 127])
# midi.NoteOffEvent(tick=22272, channel=1, data=[53, 127])
# midi.NoteOnEvent(tick=22272, channel=1, data=[62, 127])
# midi.NoteOnEvent(tick=22272, channel=1, data=[56, 127])
# midi.NoteOnEvent(tick=22272, channel=1, data=[53, 127])
# midi.NoteOffEvent(tick=22456, channel=1, data=[62, 127])
# midi.NoteOffEvent(tick=22456, channel=1, data=[56, 127])
# midi.NoteOffEvent(tick=22456, channel=1, data=[53, 127])
# midi.NoteOnEvent(tick=22456, channel=1, data=[62, 127])
# midi.NoteOnEvent(tick=22456, channel=1, data=[56, 127])
# midi.NoteOnEvent(tick=22456, channel=1, data=[53, 127])
# midi.NoteOffEvent(tick=22656, channel=1, data=[62, 127])
# midi.NoteOffEvent(tick=22656, channel=1, data=[56, 127])
# midi.NoteOffEvent(tick=22656, channel=1, data=[53, 127])
# midi.NoteOnEvent(tick=22656, channel=1, data=[62, 127])
# midi.NoteOnEvent(tick=22656, channel=1, data=[56, 127])
# midi.NoteOnEvent(tick=22656, channel=1, data=[52, 127])
# midi.NoteOffEvent(tick=22864, channel=1, data=[62, 127])
# midi.NoteOffEvent(tick=22864, channel=1, data=[56, 127])
# midi.NoteOffEvent(tick=22864, channel=1, data=[52, 127])
# midi.NoteOnEvent(tick=22864, channel=1, data=[62, 127])
# midi.NoteOnEvent(tick=22864, channel=1, data=[56, 127])
# midi.NoteOnEvent(tick=22864, channel=1, data=[52, 127])
# midi.NoteOffEvent(tick=23040, channel=1, data=[62, 127])
# midi.NoteOffEvent(tick=23040, channel=1, data=[56, 127])
# midi.NoteOffEvent(tick=23040, channel=1, data=[52, 127])
# midi.NoteOnEvent(tick=23040, channel=1, data=[62, 127])
# midi.NoteOnEvent(tick=23040, channel=1, data=[56, 127])
# midi.NoteOnEvent(tick=23040, channel=1, data=[52, 127])
# midi.NoteOffEvent(tick=23225, channel=1, data=[62, 127])
# midi.NoteOffEvent(tick=23225, channel=1, data=[56, 127])
# midi.NoteOffEvent(tick=23225, channel=1, data=[52, 127])
# midi.NoteOnEvent(tick=23225, channel=1, data=[62, 127])
# midi.NoteOnEvent(tick=23225, channel=1, data=[56, 127])
# midi.NoteOnEvent(tick=23225, channel=1, data=[52, 127])
# midi.NoteOffEvent(tick=23424, channel=1, data=[62, 127])
# midi.NoteOffEvent(tick=23424, channel=1, data=[56, 127])
# midi.NoteOffEvent(tick=23424, channel=1, data=[52, 127])
# midi.NoteOnEvent(tick=23424, channel=1, data=[62, 127])
# midi.NoteOnEvent(tick=23424, channel=1, data=[55, 127])
# midi.NoteOnEvent(tick=23424, channel=1, data=[52, 127])
# midi.NoteOffEvent(tick=23627, channel=1, data=[62, 127])
# midi.NoteOffEvent(tick=23627, channel=1, data=[55, 127])
# midi.NoteOffEvent(tick=23627, channel=1, data=[52, 127])
# midi.NoteOnEvent(tick=23627, channel=1, data=[62, 127])
# midi.NoteOnEvent(tick=23627, channel=1, data=[55, 127])
# midi.NoteOnEvent(tick=23627, channel=1, data=[52, 127])
# midi.NoteOffEvent(tick=23808, channel=1, data=[62, 127])
# midi.NoteOffEvent(tick=23808, channel=1, data=[55, 127])
# midi.NoteOffEvent(tick=23808, channel=1, data=[52, 127])
# midi.NoteOnEvent(tick=23808, channel=1, data=[61, 127])
# midi.NoteOnEvent(tick=23808, channel=1, data=[55, 127])
# midi.NoteOnEvent(tick=23808, channel=1, data=[52, 127])
# midi.NoteOffEvent(tick=24032, channel=1, data=[61, 127])
# midi.NoteOffEvent(tick=24032, channel=1, data=[55, 127])
# midi.NoteOffEvent(tick=24032, channel=1, data=[52, 127])
# midi.NoteOnEvent(tick=24032, channel=1, data=[61, 127])
# midi.NoteOnEvent(tick=24032, channel=1, data=[55, 127])
# midi.NoteOnEvent(tick=24032, channel=1, data=[52, 127])
# midi.NoteOffEvent(tick=24192, channel=1, data=[61, 127])
# midi.NoteOffEvent(tick=24192, channel=1, data=[55, 127])
# midi.NoteOffEvent(tick=24192, channel=1, data=[52, 127])
# midi.NoteOnEvent(tick=24192, channel=1, data=[58, 127])
# midi.NoteOnEvent(tick=24192, channel=1, data=[52, 127])
# midi.NoteOnEvent(tick=24192, channel=1, data=[49, 127])
# midi.NoteOffEvent(tick=24450, channel=1, data=[58, 127])
# midi.NoteOffEvent(tick=24450, channel=1, data=[52, 127])
# midi.NoteOffEvent(tick=24450, channel=1, data=[49, 127])
# midi.NoteOnEvent(tick=24450, channel=1, data=[58, 127])
# midi.NoteOnEvent(tick=24450, channel=1, data=[52, 127])
# midi.NoteOnEvent(tick=24450, channel=1, data=[49, 127])
# midi.NoteOffEvent(tick=24576, channel=1, data=[58, 127])
# midi.NoteOffEvent(tick=24576, channel=1, data=[52, 127])
# midi.NoteOffEvent(tick=24576, channel=1, data=[49, 127])
# midi.NoteOnEvent(tick=24576, channel=1, data=[57, 127])
# midi.NoteOnEvent(tick=24576, channel=1, data=[52, 127])
# midi.NoteOnEvent(tick=24576, channel=1, data=[48, 127])
# midi.NoteOffEvent(tick=24759, channel=1, data=[57, 127])
# midi.NoteOffEvent(tick=24759, channel=1, data=[52, 127])
# midi.NoteOffEvent(tick=24759, channel=1, data=[48, 127])
# midi.NoteOnEvent(tick=24759, channel=1, data=[57, 127])
# midi.NoteOnEvent(tick=24759, channel=1, data=[52, 127])
# midi.NoteOnEvent(tick=24759, channel=1, data=[48, 127])
# midi.NoteOffEvent(tick=24960, channel=1, data=[57, 127])
# midi.NoteOffEvent(tick=24960, channel=1, data=[52, 127])
# midi.NoteOffEvent(tick=24960, channel=1, data=[48, 127])
# midi.NoteOnEvent(tick=24960, channel=1, data=[47, 127])
# midi.NoteOnEvent(tick=24960, channel=1, data=[35, 127])
# midi.NoteOffEvent(tick=25145, channel=1, data=[47, 127])
# midi.NoteOffEvent(tick=25145, channel=1, data=[35, 127])
# midi.NoteOnEvent(tick=25145, channel=1, data=[69, 127])
# midi.NoteOnEvent(tick=25145, channel=1, data=[66, 127])
# midi.NoteOnEvent(tick=25145, channel=1, data=[60, 127])
# midi.NoteOnEvent(tick=25145, channel=1, data=[57, 127])
# midi.NoteOffEvent(tick=25344, channel=1, data=[69, 127])
# midi.NoteOffEvent(tick=25344, channel=1, data=[66, 127])
# midi.NoteOffEvent(tick=25344, channel=1, data=[60, 127])
# midi.NoteOffEvent(tick=25344, channel=1, data=[57, 127])
# midi.NoteOnEvent(tick=25344, channel=1, data=[69, 127])
# midi.NoteOnEvent(tick=25344, channel=1, data=[66, 127])
# midi.NoteOnEvent(tick=25344, channel=1, data=[60, 127])
# midi.NoteOnEvent(tick=25344, channel=1, data=[57, 127])
# midi.NoteOffEvent(tick=25535, channel=1, data=[69, 127])
# midi.NoteOffEvent(tick=25535, channel=1, data=[66, 127])
# midi.NoteOffEvent(tick=25535, channel=1, data=[60, 127])
# midi.NoteOffEvent(tick=25535, channel=1, data=[57, 127])
# midi.NoteOnEvent(tick=25535, channel=1, data=[69, 127])
# midi.NoteOnEvent(tick=25535, channel=1, data=[66, 127])
# midi.NoteOnEvent(tick=25535, channel=1, data=[60, 127])
# midi.NoteOnEvent(tick=25535, channel=1, data=[57, 127])
# midi.NoteOffEvent(tick=25728, channel=1, data=[69, 127])
# ...
# midi.NoteOnEvent(tick=31104, channel=1, data=[48, 127])
# midi.NoteOffEvent(tick=31326, channel=1, data=[55, 127])
# midi.NoteOffEvent(tick=31326, channel=1, data=[48, 127])
# midi.NoteOnEvent(tick=31326, channel=1, data=[55, 127])
# midi.NoteOnEvent(tick=31326, channel=1, data=[48, 127])
# midi.NoteOffEvent(tick=31488, channel=1, data=[55, 127])
# midi.NoteOffEvent(tick=31488, channel=1, data=[48, 127])
# midi.NoteOnEvent(tick=31488, channel=1, data=[55, 127])
# midi.NoteOnEvent(tick=31488, channel=1, data=[48, 127])
# midi.NoteOffEvent(tick=31661, channel=1, data=[55, 127])
# midi.NoteOffEvent(tick=31661, channel=1, data=[48, 127])
# midi.NoteOnEvent(tick=31661, channel=1, data=[55, 127])
# midi.NoteOnEvent(tick=31661, channel=1, data=[48, 127])
# midi.NoteOffEvent(tick=31872, channel=1, data=[55, 127])
# midi.NoteOffEvent(tick=31872, channel=1, data=[48, 127])
# midi.NoteOnEvent(tick=31872, channel=1, data=[58, 127])
# midi.NoteOnEvent(tick=31872, channel=1, data=[48, 127])
# midi.NoteOffEvent(tick=32046, channel=1, data=[58, 127])
# midi.NoteOffEvent(tick=32046, channel=1, data=[48, 127])
# midi.NoteOnEvent(tick=32046, channel=1, data=[58, 127])
# midi.NoteOnEvent(tick=32046, channel=1, data=[48, 127])
# midi.NoteOffEvent(tick=32256, channel=1, data=[58, 127])
# midi.NoteOffEvent(tick=32256, channel=1, data=[48, 127])
# midi.NoteOnEvent(tick=32256, channel=1, data=[57, 127])
# midi.NoteOnEvent(tick=32256, channel=1, data=[52, 127])
# midi.NoteOnEvent(tick=32256, channel=1, data=[48, 127])
# midi.NoteOffEvent(tick=32444, channel=1, data=[57, 127])
# midi.NoteOffEvent(tick=32444, channel=1, data=[52, 127])
# midi.NoteOffEvent(tick=32444, channel=1, data=[48, 127])
# midi.NoteOnEvent(tick=32444, channel=1, data=[57, 127])
# midi.NoteOnEvent(tick=32444, channel=1, data=[52, 127])
# midi.NoteOnEvent(tick=32444, channel=1, data=[48, 127])
# midi.NoteOffEvent(tick=32640, channel=1, data=[57, 127])
# midi.NoteOffEvent(tick=32640, channel=1, data=[52, 127])
# midi.NoteOffEvent(tick=32640, channel=1, data=[48, 127])
# midi.NoteOnEvent(tick=32640, channel=1, data=[57, 127])
# midi.NoteOnEvent(tick=32640, channel=1, data=[52, 127])
# midi.NoteOnEvent(tick=32640, channel=1, data=[47, 127])
# midi.NoteOffEvent(tick=32835, channel=1, data=[57, 127])
# midi.NoteOffEvent(tick=32835, channel=1, data=[52, 127])
# midi.NoteOffEvent(tick=32835, channel=1, data=[47, 127])
# midi.NoteOnEvent(tick=32835, channel=1, data=[57, 127])
# midi.NoteOnEvent(tick=32835, channel=1, data=[52, 127])
# midi.NoteOnEvent(tick=32835, channel=1, data=[47, 127])
# midi.NoteOffEvent(tick=33024, channel=1, data=[57, 127])
# midi.NoteOffEvent(tick=33024, channel=1, data=[52, 127])
# midi.NoteOffEvent(tick=33024, channel=1, data=[47, 127])
# midi.NoteOnEvent(tick=33024, channel=1, data=[56, 127])
# midi.NoteOnEvent(tick=33024, channel=1, data=[52, 127])
# midi.NoteOnEvent(tick=33024, channel=1, data=[47, 127])
# midi.NoteOffEvent(tick=33209, channel=1, data=[56, 127])
# midi.NoteOffEvent(tick=33209, channel=1, data=[52, 127])
# midi.NoteOffEvent(tick=33209, channel=1, data=[47, 127])
# midi.NoteOnEvent(tick=33209, channel=1, data=[56, 127])
# midi.NoteOnEvent(tick=33209, channel=1, data=[52, 127])
# midi.NoteOnEvent(tick=33209, channel=1, data=[47, 127])
# midi.NoteOffEvent(tick=33408, channel=1, data=[56, 127])
# midi.NoteOffEvent(tick=33408, channel=1, data=[52, 127])
# midi.NoteOffEvent(tick=33408, channel=1, data=[47, 127])
# midi.NoteOnEvent(tick=33408, channel=1, data=[55, 127])
# midi.NoteOnEvent(tick=33408, channel=1, data=[52, 127])
# midi.NoteOnEvent(tick=33408, channel=1, data=[47, 127])
# midi.NoteOffEvent(tick=33591, channel=1, data=[55, 127])
# midi.NoteOffEvent(tick=33591, channel=1, data=[52, 127])
# midi.NoteOffEvent(tick=33591, channel=1, data=[47, 127])
# midi.NoteOnEvent(tick=33591, channel=1, data=[55, 127])
# midi.NoteOnEvent(tick=33591, channel=1, data=[52, 127])
# midi.NoteOnEvent(tick=33591, channel=1, data=[47, 127])
# midi.NoteOffEvent(tick=33792, channel=1, data=[55, 127])
# midi.NoteOffEvent(tick=33792, channel=1, data=[52, 127])
# midi.NoteOffEvent(tick=33792, channel=1, data=[47, 127])
# midi.NoteOnEvent(tick=33792, channel=1, data=[55, 127])
# midi.NoteOnEvent(tick=33792, channel=1, data=[52, 127])
# midi.NoteOnEvent(tick=33792, channel=1, data=[47, 127])
# midi.NoteOffEvent(tick=33942, channel=1, data=[55, 127])
# midi.NoteOffEvent(tick=33942, channel=1, data=[52, 127])
# midi.NoteOffEvent(tick=33942, channel=1, data=[47, 127])
# midi.NoteOnEvent(tick=33942, channel=1, data=[55, 127])
# midi.NoteOnEvent(tick=33942, channel=1, data=[52, 127])
# midi.NoteOnEvent(tick=33942, channel=1, data=[47, 127])
# midi.NoteOffEvent(tick=34176, channel=1, data=[55, 127])
# midi.NoteOffEvent(tick=34176, channel=1, data=[52, 127])
# midi.NoteOffEvent(tick=34176, channel=1, data=[47, 127])
# midi.NoteOnEvent(tick=34176, channel=1, data=[55, 127])
# midi.NoteOnEvent(tick=34176, channel=1, data=[48, 127])
# midi.NoteOnEvent(tick=34176, channel=1, data=[46, 127])
# midi.NoteOffEvent(tick=34944, channel=1, data=[55, 127])
# midi.NoteOffEvent(tick=34944, channel=1, data=[48, 127])
# midi.NoteOffEvent(tick=34944, channel=1, data=[46, 127])
# midi.NoteOnEvent(tick=35712, channel=1, data=[64, 127])
# midi.NoteOnEvent(tick=35712, channel=1, data=[59, 127])
# midi.NoteOnEvent(tick=35712, channel=1, data=[54, 127])
# midi.NoteOnEvent(tick=35712, channel=1, data=[52, 127])
# midi.NoteOnEvent(tick=35712, channel=1, data=[47, 127])
# midi.NoteOnEvent(tick=35712, channel=1, data=[35, 127])
# midi.NoteOffEvent(tick=36480, channel=1, data=[64, 127])
# midi.NoteOffEvent(tick=36480, channel=1, data=[59, 127])
# midi.NoteOffEvent(tick=36480, channel=1, data=[54, 127])
# midi.NoteOffEvent(tick=36480, channel=1, data=[52, 127])
# midi.NoteOffEvent(tick=36480, channel=1, data=[47, 127])
# midi.NoteOffEvent(tick=36480, channel=1, data=[35, 127])
# midi.NoteOnEvent(tick=36480, channel=1, data=[63, 127])
# midi.NoteOnEvent(tick=36480, channel=1, data=[59, 127])
# midi.NoteOnEvent(tick=36480, channel=1, data=[54, 127])
# midi.NoteOnEvent(tick=36480, channel=1, data=[51, 127])
# midi.NoteOnEvent(tick=36480, channel=1, data=[47, 127])
# midi.NoteOnEvent(tick=36480, channel=1, data=[35, 127])
# midi.NoteOffEvent(tick=37248, channel=1, data=[63, 127])
# midi.NoteOffEvent(tick=37248, channel=1, data=[59, 127])
# midi.NoteOffEvent(tick=37248, channel=1, data=[54, 127])
# midi.NoteOffEvent(tick=37248, channel=1, data=[51, 127])
# midi.NoteOffEvent(tick=37248, channel=1, data=[47, 127])
# midi.NoteOffEvent(tick=37248, channel=1, data=[35, 127])
# midi.NoteOnEvent(tick=37248, channel=1, data=[64, 127])
# midi.NoteOnEvent(tick=37248, channel=1, data=[59, 127])
# midi.NoteOnEvent(tick=37248, channel=1, data=[55, 127])
# midi.NoteOnEvent(tick=37248, channel=1, data=[52, 127])
# midi.NoteOnEvent(tick=37248, channel=1, data=[40, 127])
# midi.NoteOnEvent(tick=37248, channel=1, data=[28, 127])
# midi.NoteOffEvent(tick=38784, channel=1, data=[64, 127])
# midi.NoteOffEvent(tick=38784, channel=1, data=[59, 127])
# midi.NoteOffEvent(tick=38784, channel=1, data=[55, 127])
# midi.NoteOffEvent(tick=38784, channel=1, data=[52, 127])
# midi.NoteOffEvent(tick=38784, channel=1, data=[40, 127])
# midi.NoteOffEvent(tick=38784, channel=1, data=[28, 127])
# midi.EndOfTrackEvent(tick=38784, data=[])
# midi.TrackNameEvent(tick=0, text='rh', data=[114, 104])
# midi.ProgramChangeEvent(tick=0, channel=1, data=[0])
# midi.InstrumentNameEvent(tick=0, text='acoustic grand', data=[97, 99, 111, 117, 115, 116, 105, 99, 32, 103, 114, 97, 110, 100])
# midi.NoteOnEvent(tick=0, channel=0, data=[59, 127])
# midi.KeySignatureEvent(tick=0, data=[1, 1])
# midi.NoteOffEvent(tick=314, channel=0, data=[59, 127])
# midi.NoteOnEvent(tick=314, channel=0, data=[71, 127])
# midi.NoteOffEvent(tick=384, channel=0, data=[71, 127])
# midi.NoteOnEvent(tick=384, channel=0, data=[71, 127])
# midi.NoteOffEvent(tick=1536, channel=0, data=[71, 127])
# midi.NoteOnEvent(tick=1536, channel=0, data=[72, 127])
# midi.NoteOffEvent(tick=1920, channel=0, data=[72, 127])
# midi.NoteOnEvent(tick=1920, channel=0, data=[71, 127])
# midi.NoteOffEvent(tick=3072, channel=0, data=[71, 127])
# midi.NoteOnEvent(tick=3072, channel=0, data=[72, 127])
# midi.NoteOffEvent(tick=3456, channel=0, data=[72, 127])
# midi.NoteOnEvent(tick=3456, channel=0, data=[71, 127])
# midi.NoteOffEvent(tick=4608, channel=0, data=[71, 127])
# midi.NoteOnEvent(tick=4608, channel=0, data=[72, 127])
# midi.NoteOffEvent(tick=4992, channel=0, data=[72, 127])
# midi.NoteOnEvent(tick=4992, channel=0, data=[71, 127])
# midi.NoteOffEvent(tick=6144, channel=0, data=[71, 127])
# midi.NoteOnEvent(tick=6144, channel=0, data=[70, 127])
# midi.NoteOffEvent(tick=6528, channel=0, data=[70, 127])
# midi.NoteOnEvent(tick=6528, channel=0, data=[69, 127])
# midi.NoteOffEvent(tick=7680, channel=0, data=[69, 127])
# midi.NoteOnEvent(tick=7680, channel=0, data=[71, 127])
# midi.NoteOffEvent(tick=8064, channel=0, data=[71, 127])
# midi.NoteOnEvent(tick=8064, channel=0, data=[69, 127])
# midi.NoteOffEvent(tick=9216, channel=0, data=[69, 127])
# midi.NoteOnEvent(tick=9216, channel=0, data=[71, 127])
# midi.NoteOffEvent(tick=9600, channel=0, data=[71, 127])
# midi.NoteOnEvent(tick=9600, channel=0, data=[69, 127])
# midi.NoteOffEvent(tick=10752, channel=0, data=[69, 127])
# midi.NoteOnEvent(tick=10752, channel=0, data=[71, 127])
# midi.NoteOffEvent(tick=11031, channel=0, data=[71, 127])
# midi.NoteOnEvent(tick=11031, channel=0, data=[69, 127])
# midi.NoteOffEvent(tick=11136, channel=0, data=[69, 127])
# midi.NoteOnEvent(tick=11136, channel=0, data=[69, 127])
# midi.NoteOffEvent(tick=12288, channel=0, data=[69, 127])
# midi.NoteOnEvent(tick=12288, channel=0, data=[68, 127])
# midi.NoteOffEvent(tick=13056, channel=0, data=[68, 127])
# midi.NoteOnEvent(tick=13056, channel=0, data=[69, 127])
# midi.NoteOffEvent(tick=13263, channel=0, data=[69, 127])
# midi.NoteOnEvent(tick=13263, channel=0, data=[71, 127])
# midi.NoteOffEvent(tick=13440, channel=0, data=[71, 127])
# midi.NoteOnEvent(tick=13440, channel=0, data=[74, 127])
# midi.NoteOffEvent(tick=13628, channel=0, data=[74, 127])
# midi.NoteOnEvent(tick=13628, channel=0, data=[72, 127])
# midi.NoteOffEvent(tick=13824, channel=0, data=[72, 127])
# midi.NoteOnEvent(tick=13824, channel=0, data=[64, 127])
# midi.NoteOffEvent(tick=14003, channel=0, data=[64, 127])
# midi.NoteOnEvent(tick=14003, channel=0, data=[69, 127])
# midi.NoteOffEvent(tick=14208, channel=0, data=[69, 127])
# midi.NoteOnEvent(tick=14208, channel=0, data=[66, 127])
# midi.NoteOffEvent(tick=15360, channel=0, data=[66, 127])
# midi.NoteOnEvent(tick=15360, channel=0, data=[69, 127])
# midi.NoteOffEvent(tick=15744, channel=0, data=[69, 127])
# midi.NoteOnEvent(tick=15744, channel=0, data=[66, 127])
# midi.NoteOnEvent(tick=16805, channel=0, data=[71, 127])
# midi.NoteOffEvent(tick=16896, channel=0, data=[66, 127])
# midi.NoteOnEvent(tick=16896, channel=0, data=[69, 127])
# midi.NoteOffEvent(tick=17081, channel=0, data=[71, 127])
# midi.NoteOffEvent(tick=17280, channel=0, data=[69, 127])
# midi.NoteOnEvent(tick=17280, channel=0, data=[67, 127])
# midi.NoteOffEvent(tick=17497, channel=0, data=[67, 127])
# midi.NoteOnEvent(tick=17497, channel=0, data=[66, 127])
# midi.NoteOffEvent(tick=17664, channel=0, data=[66, 127])
# midi.NoteOnEvent(tick=17664, channel=0, data=[60, 127])
# midi.NoteOffEvent(tick=17860, channel=0, data=[60, 127])
# midi.NoteOnEvent(tick=17860, channel=0, data=[59, 127])
# midi.NoteOffEvent(tick=18048, channel=0, data=[59, 127])
# midi.NoteOnEvent(tick=18048, channel=0, data=[63, 127])
# midi.NoteOffEvent(tick=18219, channel=0, data=[63, 127])
# midi.NoteOnEvent(tick=18219, channel=0, data=[66, 127])
# midi.NoteOffEvent(tick=18432, channel=0, data=[66, 127])
# midi.NoteOnEvent(tick=18432, channel=0, data=[74, 127])
# midi.NoteOffEvent(tick=18568, channel=0, data=[74, 127])
# midi.NoteOnEvent(tick=18568, channel=0, data=[72, 127])
# midi.NoteOffEvent(tick=18683, channel=0, data=[72, 127])
# midi.NoteOnEvent(tick=18683, channel=0, data=[71, 127])
# midi.NoteOffEvent(tick=18816, channel=0, data=[71, 127])
# midi.NoteOnEvent(tick=18816, channel=0, data=[71, 127])
# midi.NoteOffEvent(tick=19968, channel=0, data=[71, 127])
# midi.NoteOnEvent(tick=19968, channel=0, data=[72, 127])
# midi.NoteOffEvent(tick=20352, channel=0, data=[72, 127])
# midi.NoteOnEvent(tick=20352, channel=0, data=[71, 127])
# midi.NoteOffEvent(tick=21504, channel=0, data=[71, 127])
# midi.NoteOnEvent(tick=21504, channel=0, data=[72, 127])
# midi.NoteOffEvent(tick=21888, channel=0, data=[72, 127])
# midi.NoteOnEvent(tick=21888, channel=0, data=[71, 127])
# midi.NoteOffEvent(tick=23040, channel=0, data=[71, 127])
# midi.NoteOnEvent(tick=23040, channel=0, data=[72, 127])
# midi.NoteOffEvent(tick=23424, channel=0, data=[72, 127])
# midi.NoteOnEvent(tick=23424, channel=0, data=[71, 127])
# midi.NoteOffEvent(tick=23706, channel=0, data=[71, 127])
# midi.NoteOnEvent(tick=23706, channel=0, data=[70, 127])
# midi.NoteOffEvent(tick=23808, channel=0, data=[70, 127])
# midi.NoteOnEvent(tick=23808, channel=0, data=[70, 127])
# midi.NoteOffEvent(tick=24192, channel=0, data=[70, 127])
# midi.NoteOnEvent(tick=24192, channel=0, data=[81, 127])
# midi.NoteOffEvent(tick=24576, channel=0, data=[81, 127])
# midi.NoteOnEvent(tick=24576, channel=0, data=[78, 127])
# midi.NoteOffEvent(tick=24827, channel=0, data=[78, 127])
# midi.NoteOnEvent(tick=24827, channel=0, data=[76, 127])
# midi.NoteOffEvent(tick=24960, channel=0, data=[76, 127])
# midi.NoteOnEvent(tick=24960, channel=0, data=[76, 127])
# midi.NoteOffEvent(tick=25145, channel=0, data=[76, 127])
# midi.NoteOnEvent(tick=25145, channel=0, data=[75, 127])
# midi.NoteOffEvent(tick=25344, channel=0, data=[75, 127])
# midi.NoteOnEvent(tick=25344, channel=0, data=[84, 127])
# midi.NoteOffEvent(tick=25535, channel=0, data=[84, 127])
# midi.NoteOnEvent(tick=25535, channel=0, data=[75, 127])
# midi.NoteOffEvent(tick=25728, channel=0, data=[75, 127])
# midi.NoteOnEvent(tick=25728, channel=0, data=[75, 127])
# midi.NoteOffEvent(tick=25916, channel=0, data=[75, 127])
# midi.NoteOnEvent(tick=25916, channel=0, data=[76, 127])
# midi.NoteOffEvent(tick=26112, channel=0, data=[76, 127])
# midi.NoteOnEvent(tick=26112, channel=0, data=[79, 127])
# midi.NoteOffEvent(tick=26285, channel=0, data=[79, 127])
# midi.NoteOnEvent(tick=26285, channel=0, data=[71, 127])
# midi.NoteOffEvent(tick=26496, channel=0, data=[71, 127])
# midi.NoteOnEvent(tick=26496, channel=0, data=[74, 127])
# midi.NoteOffEvent(tick=26690, channel=0, data=[74, 127])
# midi.NoteOnEvent(tick=26690, channel=0, data=[72, 127])
# midi.NoteOffEvent(tick=26880, channel=0, data=[72, 127])
# midi.NoteOnEvent(tick=26880, channel=0, data=[76, 127])
# midi.NoteOffEvent(tick=27005, channel=0, data=[76, 127])
# midi.NoteOnEvent(tick=27005, channel=0, data=[64, 127])
# midi.NoteOffEvent(tick=27125, channel=0, data=[64, 127])
# midi.NoteOnEvent(tick=27125, channel=0, data=[69, 127])
# midi.NoteOffEvent(tick=27264, channel=0, data=[69, 127])
# midi.NoteOnEvent(tick=27264, channel=0, data=[66, 127])
# midi.NoteOffEvent(tick=27824, channel=0, data=[66, 127])
# midi.NoteOnEvent(tick=27824, channel=0, data=[69, 127])
# midi.NoteOffEvent(tick=28032, channel=0, data=[69, 127])
# midi.NoteOnEvent(tick=28032, channel=0, data=[66, 127])
# midi.NoteOnEvent(tick=29097, channel=0, data=[71, 127])
# midi.NoteOffEvent(tick=29184, channel=0, data=[66, 127])
# midi.NoteOnEvent(tick=29184, channel=0, data=[69, 127])
# midi.NoteOffEvent(tick=29319, channel=0, data=[71, 127])
# midi.NoteOffEvent(tick=29568, channel=0, data=[69, 127])
# midi.NoteOnEvent(tick=29568, channel=0, data=[66, 127])
# midi.NoteOffEvent(tick=30963, channel=0, data=[66, 127])
# midi.NoteOnEvent(tick=30963, channel=0, data=[64, 127])
# midi.NoteOffEvent(tick=31104, channel=0, data=[64, 127])
# midi.NoteOnEvent(tick=31104, channel=0, data=[64, 127])
# midi.NoteOffEvent(tick=32256, channel=0, data=[64, 127])
# midi.NoteOnEvent(tick=32256, channel=0, data=[66, 127])
# midi.NoteOffEvent(tick=32640, channel=0, data=[66, 127])
# midi.NoteOnEvent(tick=32640, channel=0, data=[64, 127])
# midi.NoteOffEvent(tick=33792, channel=0, data=[64, 127])
# midi.NoteOnEvent(tick=33792, channel=0, data=[66, 127])
# midi.NoteOffEvent(tick=34176, channel=0, data=[66, 127])
# midi.NoteOnEvent(tick=34176, channel=0, data=[64, 127])
# midi.NoteOffEvent(tick=34944, channel=0, data=[64, 127])
# midi.EndOfTrackEvent(tick=34944, data=[])
